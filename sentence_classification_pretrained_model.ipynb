# %% [markdown]
# <a href="https://colab.research.google.com/github/kathdevx/emotionalAI/blob/main/sentence_classification_pretrained_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install git+https://github.com/huggingface/transformers
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-yc1xs97s
#   Running command git clone -q https://github.com/huggingface/transformers /tmp/pip-req-build-yc1xs97s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 636 kB 2.6 MB/s
# ...
#      |████████████████████████████████| 895 kB 46.6 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 31.5 MB/s
# ...
#      |████████████████████████████████| 50 kB 5.4 MB/s
# ...
#   Created wheel for transformers: filename=transformers-4.11.0.dev0-py3-none-any.whl size=2817596 sha256=1d1cac69db4142f9468bbcbd12664111853c8ddec57b4c3c11082867e10ffeea
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6wlklri_/wheels/35/2e/a7/d819e3310040329f0f47e57c9e3e7a7338aa5e74c49acfe522
# Successfully built transformers
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
# ...

# %%
import pickle
import json
from transformers import pipeline

classifier = pipeline("text-classification",model='bhadresh-savani/distilbert-base-uncased-emotion', return_all_scores=True)

range_3 = range(436, 636)

global_counter = range_3[0]

while global_counter <= range_3[-1]:
    print(f'----------- Epoch {global_counter} ----------- \n')
    inname = '/content/drive/Shareddrives/DNN -  audio files/Podcasts_Dataset/Data/training sentences/train_sentences_chunk_' + str(global_counter) + '.txt'
    outname = '/content/drive/Shareddrives/DNN -  audio files/Podcasts_Dataset/Data/train classified sentences/train_classified_sentences_chunk_' + str(global_counter) + '.txt'

    train_chunk = None
    with open(inname, 'r') as infile:
        train_chunk = infile.readlines()
    with open(outname, 'w') as outfile:
        for t in train_chunk:
            temp = t.split(' ', 1)
            fname = temp[0] + ' '
            outfile.write(fname)
            outfile.write(json.dumps(classifier(temp[1],)))
            outfile.write('\n')
    global_counter +=1
# Out:
# Downloading:   0%|          | 0.00/783 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/291 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ----------- Epoch 436 -----------
#
# ----------- Epoch 437 -----------
#
# ----------- Epoch 438 -----------
#
# ----------- Epoch 439 -----------
#
# ----------- Epoch 440 -----------
#
# ----------- Epoch 441 -----------
#
# ----------- Epoch 442 -----------
#
# ----------- Epoch 443 -----------
#
# ----------- Epoch 444 -----------
#
# ----------- Epoch 445 -----------
#
# ----------- Epoch 446 -----------
#
# ----------- Epoch 447 -----------
#
# ----------- Epoch 448 -----------
#
# ----------- Epoch 449 -----------
#
# ----------- Epoch 450 -----------
#
# ----------- Epoch 451 -----------
#
# ----------- Epoch 452 -----------
#
# ----------- Epoch 453 -----------
#
# ...
